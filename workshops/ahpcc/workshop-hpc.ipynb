# %% [markdown]
# # AIMRC Data Science Core Workshop on Using AHPCC
#
# - Link to [Google Drive Data folder](https://drive.google.com/drive/folders/1_IlfCe9hak_ggr7v2aydl-Zg21vIep3K?usp=sharing). Please download the `workshop-hpc-data` folder.
# - Link to [Github Repository](https://github.com/pv-is-nrt/aimrc-data-science-core). Please download the repository by going to Code (green button) > Download ZIP.
# - Link to [download PuTTY Installer](https://the.earth.li/~sgtatham/putty/latest/w64/putty-64bit-0.81-installer.msi) for Windows
# - Link to [download Fiji](https://downloads.imagej.net/fiji/latest/fiji-linux64.zip) for Linux

# %% [markdown]
# ## Exercise 1: Here we go!
#
# In this exercise, you learned how to log into the Pinnacle Desktop and how to navigate the system. This exercise was done outside of the Jupyter notebook environment, of course.
#
# Make sure you
# 1. Logged in to Pinnacle in your browser.
# 2. Opened a Pinnacle Desktop session within your browser.
# 3. Accessed Firefox browser within the Pinnacle Desktop session.
# 4. Downloaded the `workshop-hpc-data` folder from the Google Drive link above.
# 5. Downloaded the Github repository from the link above.
# 6. Extracted both downloaded zip files to your home/downloads directory. Right click in the downloaded zip file and click on Extract Here.
# 7. You are free to download/extract your files to any directory you prefer. But if you followed the instructions above, you Home/Downloads directory should look like this:
#
#     ```bash
#     /home/username/Downloads/
#         ├── aimrc-data-science-core-main
#         ├── workshop-hpc-data
#         ├── aimrc-data-science-core-main.zip
#         └── workshop-hpc-data-20240724T162726Z-001.zip
#     ```

# %% [markdown]
# ## Exercise 2: Basic Shell Commands
#
# In this exercise, you learned about logging into the Pinnacle server using SSH and running basic shell commands. You downloaded and installed PuTTY (link above) for this.
#
# Type the following in PuTTY Configuration window and click 'Open':
# Host Name or IP address:
# *username@hpc-portal2.hpc.uark.edu*
#
# Practice running the following commands
# ```bash
#     - env
#     - who
#     - whoami
#     - hostname
#     - date
#     - df
#     - cd /home/username/Downloads
#     - ls -al
# ```
#
# This exercise was done outside of the Jupyter notebook environment.

# %% [markdown]
# ## Exercise 3: What have I gotten myself into?

# %% [markdown]
# ### Get basic information about the hardware

# %%
# we import psutil that allows us to interact with the system processes
import psutil

# print the number of CPU cores available and the percent usage
print("Number of CPU cores:", psutil.cpu_count())
print("CPU usage:", psutil.cpu_percent(interval=1), "%")

# print the total and used memory on the system
memory = psutil.virtual_memory()
print("Total memory:", memory.total / (1024 * 1024 * 1024), "GB")
print("Used memory:", memory.used / (1024 * 1024 * 1024), "GB")

# print the amount of GPU memory on the system
gpu_memory = psutil.virtual_memory()
print("Total GPU memory:", gpu_memory.total / (1024 * 1024 * 1024), "GB")
print("Used GPU memory:", gpu_memory.used / (1024 * 1024 * 1024), "GB")

# print the storage information on the system
disk_partitions = psutil.disk_partitions()
for d_p in disk_partitions:
    print("Device: " + d_p.device + "; "
          "Mountpoint: " + d_p.mountpoint + "; "
          "File system type: " + d_p.fstype)
disk_usage = psutil.disk_usage('/')
print("Total disk space:", disk_usage.total / (1024 * 1024 * 1024), "GB")
print("Used disk space:", disk_usage.used / (1024 * 1024 * 1024), "GB")
# Out:
# Number of CPU cores: 8
# CPU usage: 28.1 %
# Total memory: 31.960521697998047 GB
# Used memory: 16.200885772705078 GB
# Total GPU memory: 31.960521697998047 GB
# Used GPU memory: 16.200843811035156 GB
# Device: C:\; Mountpoint: C:\; File system type: NTFS
# Device: D:\; Mountpoint: D:\; File system type: NTFS
# Device: E:\; Mountpoint: E:\; File system type: NTFS
# Device: P:\; Mountpoint: P:\; File system type:
# Total disk space: 932.6171836853027 GB
# Used disk space: 915.7942085266113 GB

# %% [markdown]
# We can get detailed information about the Nvidia GPU by using the nvidia-smi utility.
# Note that you can use shell commands in Jupyter Notebooks by prefixing the command with an exclamation mark (!).

# %%
# !nvidia-smi
# Out:
# Wed Jul 24 01:45:40 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 536.23                 Driver Version: 536.23       CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce GTX 1070      WDDM  | 00000000:01:00.0  On |                  N/A |
# | 10%   54C    P0              29W / 185W |   1775MiB /  8192MiB |      4%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      3236    C+G   ...siveControlPanel\SystemSettings.exe    N/A      |
# |    0   N/A  N/A      5552    C+G   ...\4KDownload\4kstogram\4kstogram.exe    N/A      |
# |    0   N/A  N/A      9036    C+G   ...GeForce Experience\NVIDIA Share.exe    N/A      |
# |    0   N/A  N/A     10268    C+G   ...S Code Insiders\Code - Insiders.exe    N/A      |
# |    0   N/A  N/A     10344    C+G   ...FancyZones\PowerToys.FancyZones.exe    N/A      |
# |    0   N/A  N/A     10808    C+G   C:\Windows\explorer.exe                   N/A      |
# |    0   N/A  N/A     13192    C+G   ...2txyewy\StartMenuExperienceHost.exe    N/A      |
# |    0   N/A  N/A     13496    C+G   ....Search_cw5n1h2txyewy\SearchApp.exe    N/A      |
# |    0   N/A  N/A     14448    C+G   ...B\system_tray\lghub_system_tray.exe    N/A      |
# |    0   N/A  N/A     14800    C+G   ...t.LockApp_cw5n1h2txyewy\LockApp.exe    N/A      |
# |    0   N/A  N/A     15516    C+G   ...GeForce Experience\NVIDIA Share.exe    N/A      |
# |    0   N/A  N/A     15576    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe    N/A      |
# |    0   N/A  N/A     17196    C+G   ...oogle\Chrome\Application\chrome.exe    N/A      |
# |    0   N/A  N/A     18980    C+G   ...inaries\Win64\EpicGamesLauncher.exe    N/A      |
# |    0   N/A  N/A     21632    C+G   ...5n1h2txyewy\ShellExperienceHost.exe    N/A      |
# |    0   N/A  N/A     21916    C+G   ...cal\Microsoft\OneDrive\OneDrive.exe    N/A      |
# |    0   N/A  N/A     22348    C+G   ...aam7r\AcrobatNotificationClient.exe    N/A      |
# |    0   N/A  N/A     24328    C+G   ...deodownloader\4kvideodownloader.exe    N/A      |
# |    0   N/A  N/A     24696    C+G   ...les (x86)\Battle.net\Battle.net.exe    N/A      |
# |    0   N/A  N/A     25860    C+G   ...crosoft\Edge\Application\msedge.exe    N/A      |
# |    0   N/A  N/A     26672    C+G   ...0.0_x64__cv1g1gvanyjgm\WhatsApp.exe    N/A      |
# |    0   N/A  N/A     27720    C+G   ...n\126.0.2592.113\msedgewebview2.exe    N/A      |
# |    0   N/A  N/A     28784    C+G   ...ne\Binaries\Win64\EpicWebHelper.exe    N/A      |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ### Get information about the packages installed

# %%
# print the list of packages installed in the current environment
# !conda list
# Out:
# 'conda' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## Exercise 4: Running a simple Python script in Jupyter Notebook
#
# In this exercise, we will run a simple Python program in Jupyter Notebook. We write a program to crop images and save the cropped images in a new folder.

# %%
# !pip install pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pillow
#   Downloading pillow-10.4.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Downloading pillow-10.4.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 20.1 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pillow
# Successfully installed pillow-10.4.0

# %%
from pathlib import Path
import PIL.Image as Image

DATA_FOLDER = '/home/prateek/Downloads/workshop-hpc-data/NFFA images sampled'
TARGET_FOLDER = '/home/prateek/Downloads/workshop-hpc-data/NFFA images sampled cropped'

# Create target folder if it does not exist
Path(TARGET_FOLDER).mkdir(parents=True, exist_ok=True)

# %%
# get the list of all files in the source folder
files = list(Path(DATA_FOLDER).rglob('*.jpg'))
print(len(files), 'total files found')

# get the dimension of the first image
img = Image.open(files[0])
print('Dimensions of the first image:', img.size)
# Out:
# 250
# (1024, 768)

# %%
# define the cropping function
def crop_image(file, data_folder, target_folder):
    img = Image.open(file)
    img = img.crop((0, 0, 1024, 600))
    # save the cropped image in the target folder matching the subfolder structure
    save_to_path = str(file).replace(data_folder, target_folder)
    # make sure the subfolder exists
    Path(save_to_path).parent.mkdir(parents=True, exist_ok=True)
    img.save(save_to_path)
    print('saved ' + save_to_path)

# %%
# crop all images
for file in files:
    crop_image(file, DATA_FOLDER, TARGET_FOLDER)
# Out:
# saved /home/prateek/Downloads/NFFA images sampled cropped/Porous_Sponge/ee3dd72b977b5f4b32f3d25410831662.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Porous_Sponge/76790e49cb19cde496a02ac9f4d69bc9.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Porous_Sponge/cf9f11694caad1e286bedf582bb45456.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Porous_Sponge/7a872105aa1ac4c258cfaccfa006927d.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Porous_Sponge
jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Nanowires/4ff6ac77b6f342d6d4ca85a1ff9e0171.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Nanowires/0005e11b6e8df81ad5aba66e6c39370b.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Nanowires/572f0d51da87284fd1d95f32161c6af6.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Nanowires/a5024441ef40951fb7d61fea478a464a.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Nanowires/faaea8dbb666423b53689d75306885e3.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Nanowires/b00c36659b4fd823aa7bb75bb804951f.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Nanowires/98a64a72509bad1014645dbb3de6362f.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Nanowires/05ca59d4646c5c1127454f51c05af135.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Nanowires/a7a70b46fe5fccc90782ac4e06153ffa.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Nanowires/7107b58ff23b28a454a7efeff11ebf1c.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Nanowires/d92225e4bcc560b5185f8bd08be60a05.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Nanowires/096c94d2b31835792c94514ce7857038.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Nanowires/d0067d9a5ae32f8e1a8e2bf8fc7b63ef.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Nanowires/7878ddace938e835ed7a6aafc3ca4ae9.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Nanowires/9fb1471283fc9b4d3c5fa1200776efbe.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Nanowires/80d1a91b33654fee7b61a394f5e36dea.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Nanowires/87e9025a9cccd57c00a54723e0423359.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Patterned_surface/eb2421a7de44fe19aed78097463b1c58.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Patterned_surface/b4a3462d0f96fd388b60ec4f23dbd41f.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Patterned_surface/71682c3b54f83a3267475a9833023695.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Patterned_surface/38bc2799a85cd6fa7b570f691a0341ff.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Patterned_surface/cdb3caf1c93dad62c1f608a38bf7e16e.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Patterned_surface/ebde22d032a23f16906f9032a460a3b5.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Patterned_surface/8df5f61e4aab0b661ae53636e3b6c70d.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Patterned_surface/6e68ca7ca70886c8b02b893ab5e276c9.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Patterned_surface/15d8adf71eb40073c531d3a85afbf1f3.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Patterned_surface/67114a78d86a982c491e38e556a42bd8.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Patterned_surface/486274b34cc86074acc7c1cf2b1c0b71.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Patterned_surface/1ea300bb12ab99e58e7b34a1b2f172fa.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Patterned_surface/079dc28a4073b566494489363518ab68.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Patterned_surface/821bde9cb2ba056b97d1191ac0eaa42a.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Patterned_surface/1a45e974c0664dc98efb637a81c873db.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Patterned_surface/621abf3e66e61b1ddf6fee341dd26536.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Patterned_surface/58e11a9c2e3749d8dcdd029bf534c615.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Patterned_surface/fa084535f793e807d0bc062fb161e8b7.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Patterned_surface/e6b92b79b330d0b92f5ccbb2b35abf72.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Patterned_surface/a7cec479c28cd0d9aeaa9694a6dd83b2.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Patterned_surface/28d579293481e312304252b5df109a52.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Patterned_surface/9322a1b66ed1d3b5ddaf6eab289aa461.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Patterned_surface/f63510128c7aeacbf754cdb8d5022d19.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Patterned_surface/7b02f07cdfaefc848c3385ada806481c.jpg
# saved /home/prateek/Downloads/NFFA images sampled cropped/Patterned_surface/3950ac285bdaf6a15f2bc12262ddca23.jpg

# %% [markdown]
# ## Exercise 5: Running jobs on the Pinnacle cluster
#
# In this exercise, you learned about submitting jobs to the Pinnacle server through the SSH terminal. This exercise was done outside of the Jupyter notebook environment.
#
# Make sure you:
# - changed into the /workshops/ahpcc directory
#     `cd /home/USERNAME/Downloads/aimrc-data-science-core-main/workshops/ahpcc`
# - activate base environment
#     `module load python/3.10-anaconda`
#     `which python`
#     `source /share/apps/bin/conda-3.10.sh`
# - submit a Python script as a job (independent of previous jobs)
#     `sinfo`
#     `squeue`
#     `sbatch --partition pcon06 --constraint 'aimrc' --nodes=1 myjob.sh`

# %% [markdown]
# ## Exercise 6: Fiji
#
# In this exercise, you learned about logging into the Pinnacle Desktop, browsing the internet, downloading and installing Fiji and using Fiji to open and process an image file.
#
# Make sure you:
# - Downloaded (link at the top) and extracted Fiji
# - Launched `Fiji` executable file
# - Used one of the NFFA microscopy images to do an image processing of your choice in Fiji and saved your result in your Documents folder.

# %% [markdown]
# ## Exercise 7: A machine learning experiment
#
# In this exercise, we write a simple machine learning program to classify the images you downloaded from the Google Drive folder. We will train a simple CNN model to classify the images.
